# %%
from raphtory import Graph
import pandas as pd
import os

# Load data
df_kpi = pd.read_csv("./kiali_kpi_metrics.csv")

# Round timestamp to the nearest minute
df_kpi['timestamp'] = pd.to_datetime(df_kpi['timestamp']).dt.floor('min')

# Convert timestamp to Unix time (seconds since epoch)
df_kpi['timestamp'] = pd.to_datetime(df_kpi['timestamp']).astype(int) // 10**9

# Multi-class labeling
def classify_error(er):
    if er < 0.01:
        return 0
    elif er < 0.15:
        return 1
    else:
        return 2

df_kpi["status"] = df_kpi["error_rate"].apply(classify_error)

# Function to assign color based on status
def get_color(status):
    if status == 0:
        return "green"
    elif status == 1:
        return "orange"
    elif status == 2:
        return "red"

# Create communication graph
g = Graph()
for _, row in df_kpi.iterrows():
    ts = int(row["timestamp"])
    src = str(row["source_workload"])
    dst = str(row["destination_workload"])
    status = row["status"]
    color = get_color(status)  # Get color based on status
    
    # Add nodes
    g.add_node(timestamp=ts, id=src, properties={"role": "source"})
    g.add_node(timestamp=ts, id=dst, properties={"role": "destination"})
    
    # Add edge with color and name based on status
    g.add_edge(
        timestamp=ts,
        src=src,
        dst=dst,
        properties={
            "status": status,
            "throughput": row.get("throughput", 0.0),
            "color": color,  # Add color property
            "name": f"status_{status}"  # Add name property based on status
        }
    )
    print(f"Adding edge: {src} -> {dst}, Properties: {{'status': {status}, 'throughput': {row.get('throughput', 0.0)}, 'color': {color}, 'name': 'status_{status}'}}")
# Save graph
output_dir = "graphs/communication_graph"
if os.path.exists(output_dir):
    import shutil
    shutil.rmtree(output_dir)  # Remove the directory if it already exists
os.makedirs("graphs/", exist_ok=True)
g.save_to_file("graphs/communication_graph")
print("✅ Communication graph saved.")
# Out:
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': nan, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 539.0, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 445.1666666666667, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 549.8333333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 568.1666666666666, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 516.0833333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 624.6666666666666, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 575.0, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 376.0, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 16.666666666666668, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 16.666666666666668, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 171.33333333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 261.1666666666667, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 359.3333333333333, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 486.9166666666667, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 386.4166666666667, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 516.0833333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 532.75, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 493.1666666666667, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 551.5, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 591.3333333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 614.4166666666666, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 635.0833333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 528.5833333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 395.0, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 206.75, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 37.5, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': nan, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 578.75, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 692.0833333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 823.5, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 861.8333333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 870.5833333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 905.0833333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 819.6666666666666, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 470.3333333333333, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 15.333333333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 41.333333333333336, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 250.5, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 355.0833333333333, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 510.5833333333333, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 662.25, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 551.9166666666666, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 810.0833333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 757.25, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 692.0833333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 700.5833333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 1006.9166666666666, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 949.1666666666666, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 913.8333333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 732.3333333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 419.4166666666667, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 332.0833333333333, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 36.41666666666666, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': nan, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 545.9166666666666, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 583.0833333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 620.5833333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 714.0833333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 668.9166666666666, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 720.25, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 732.75, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 281.8333333333333, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 11.666666666666666, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 45.083333333333336, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 252.33333333333331, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 334.5833333333333, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 454.0, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 590.1666666666666, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 463.3333333333333, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 713.6666666666666, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 609.0, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 637.9166666666666, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 626.3333333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 727.5833333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 786.5, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 801.5833333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 630.5833333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 242.25, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 271.25, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 41.333333333333336, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 0, 'throughput': nan, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 0, 'throughput': 298.0, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 0, 'throughput': 245.91666666666663, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 0, 'throughput': 282.0833333333333, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 1, 'throughput': 300.0833333333333, 'color': orange, 'name': 'status_1'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 1, 'throughput': 275.3333333333333, 'color': orange, 'name': 'status_1'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 1, 'throughput': 333.25, 'color': orange, 'name': 'status_1'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 0, 'throughput': 318.0833333333333, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 0, 'throughput': 250.75, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 0, 'throughput': 9.0, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 0, 'throughput': 6.75, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 0, 'throughput': 82.83333333333333, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# ...
# Adding edge: checkoutservice -> shippingservice, Properties: {'status': 0, 'throughput': 339.3666666666667, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> shippingservice, Properties: {'status': 0, 'throughput': 720.8, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> shippingservice, Properties: {'status': 0, 'throughput': 815.7833333333333, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> shippingservice, Properties: {'status': 0, 'throughput': 70.23333333333333, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> adservice, Properties: {'status': 1, 'throughput': nan, 'color': orange, 'name': 'status_1'}
# Adding edge: frontend -> adservice, Properties: {'status': 1, 'throughput': 3050.6583333333333, 'color': orange, 'name': 'status_1'}
# Adding edge: frontend -> adservice, Properties: {'status': 1, 'throughput': 1673.1816666666666, 'color': orange, 'name': 'status_1'}
# Adding edge: frontend -> adservice, Properties: {'status': 1, 'throughput': 3733.9816666666666, 'color': orange, 'name': 'status_1'}
# Adding edge: frontend -> adservice, Properties: {'status': 1, 'throughput': 3934.87, 'color': orange, 'name': 'status_1'}
# Adding edge: frontend -> adservice, Properties: {'status': 1, 'throughput': 372.425, 'color': orange, 'name': 'status_1'}
# Adding edge: frontend -> cartservice, Properties: {'status': 0, 'throughput': nan, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> cartservice, Properties: {'status': 0, 'throughput': 5444.65, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> cartservice, Properties: {'status': 0, 'throughput': 3483.983333333333, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> cartservice, Properties: {'status': 0, 'throughput': 7144.8, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> cartservice, Properties: {'status': 0, 'throughput': 6964.75, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> cartservice, Properties: {'status': 0, 'throughput': 806.8, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> checkoutservice, Properties: {'status': 0, 'throughput': nan, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> checkoutservice, Properties: {'status': 1, 'throughput': 367.73333333333335, 'color': orange, 'name': 'status_1'}
# Adding edge: frontend -> checkoutservice, Properties: {'status': 0, 'throughput': 262.7, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> checkoutservice, Properties: {'status': 0, 'throughput': 472.3, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> checkoutservice, Properties: {'status': 1, 'throughput': 484.76666666666665, 'color': orange, 'name': 'status_1'}
# Adding edge: frontend -> checkoutservice, Properties: {'status': 1, 'throughput': 50.5, 'color': orange, 'name': 'status_1'}
# Adding edge: frontend -> currencyservice, Properties: {'status': 0, 'throughput': nan, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> currencyservice, Properties: {'status': 0, 'throughput': 14678.6, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> currencyservice, Properties: {'status': 0, 'throughput': 11097.633333333331, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> currencyservice, Properties: {'status': 0, 'throughput': 20716.25, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> currencyservice, Properties: {'status': 0, 'throughput': 19058.483333333334, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> currencyservice, Properties: {'status': 0, 'throughput': 2208.266666666667, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> productcatalogservice, Properties: {'status': 0, 'throughput': nan, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> productcatalogservice, Properties: {'status': 0, 'throughput': 22460.325, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> productcatalogservice, Properties: {'status': 0, 'throughput': 15925.345, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> productcatalogservice, Properties: {'status': 0, 'throughput': 30857.12, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> productcatalogservice, Properties: {'status': 0, 'throughput': 29218.046666666665, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> productcatalogservice, Properties: {'status': 0, 'throughput': 3322.1916666666666, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> recommendationservice, Properties: {'status': 0, 'throughput': nan, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> recommendationservice, Properties: {'status': 0, 'throughput': 5719.283333333334, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> recommendationservice, Properties: {'status': 0, 'throughput': 2902.083333333333, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> recommendationservice, Properties: {'status': 0, 'throughput': 6651.383333333333, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> recommendationservice, Properties: {'status': 0, 'throughput': 7237.883333333333, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> recommendationservice, Properties: {'status': 1, 'throughput': 733.6333333333333, 'color': orange, 'name': 'status_1'}
# Adding edge: frontend -> shippingservice, Properties: {'status': 0, 'throughput': nan, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> shippingservice, Properties: {'status': 0, 'throughput': 1354.0666666666666, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> shippingservice, Properties: {'status': 0, 'throughput': 692.275, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> shippingservice, Properties: {'status': 0, 'throughput': 1540.7083333333333, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> shippingservice, Properties: {'status': 0, 'throughput': 1644.9566666666667, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> shippingservice, Properties: {'status': 0, 'throughput': 153.79166666666666, 'color': green, 'name': 'status_0'}
# Adding edge: loadgenerator -> frontend, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: loadgenerator -> frontend, Properties: {'status': 2, 'throughput': 39754.36666666667, 'color': red, 'name': 'status_2'}
# Adding edge: loadgenerator -> frontend, Properties: {'status': 2, 'throughput': 29427.6, 'color': red, 'name': 'status_2'}
# Adding edge: loadgenerator -> frontend, Properties: {'status': 2, 'throughput': 55182.75, 'color': red, 'name': 'status_2'}
# Adding edge: loadgenerator -> frontend, Properties: {'status': 2, 'throughput': 47157.75, 'color': red, 'name': 'status_2'}
# Adding edge: loadgenerator -> frontend, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: recommendationservice -> productcatalogservice, Properties: {'status': 0, 'throughput': nan, 'color': green, 'name': 'status_0'}
# Adding edge: recommendationservice -> productcatalogservice, Properties: {'status': 0, 'throughput': 3361.41, 'color': green, 'name': 'status_0'}
# Adding edge: recommendationservice -> productcatalogservice, Properties: {'status': 0, 'throughput': 2452.3166666666666, 'color': green, 'name': 'status_0'}
# Adding edge: recommendationservice -> productcatalogservice, Properties: {'status': 0, 'throughput': 4688.071666666667, 'color': green, 'name': 'status_0'}
# Adding edge: recommendationservice -> productcatalogservice, Properties: {'status': 0, 'throughput': 4407.528333333334, 'color': green, 'name': 'status_0'}
# Adding edge: recommendationservice -> productcatalogservice, Properties: {'status': 0, 'throughput': 513.465, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': nan, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 340.3833333333333, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 524.4333333333333, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> cartservice, Properties: {'status': 0, 'throughput': 24.425, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': nan, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 490.075, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 753.3583333333333, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> currencyservice, Properties: {'status': 0, 'throughput': 36.85, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': nan, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 409.15833333333336, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 623.875, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> emailservice, Properties: {'status': 0, 'throughput': 31.258333333333333, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 0, 'throughput': nan, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 0, 'throughput': 183.75833333333333, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 0, 'throughput': 285.68333333333334, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> paymentservice, Properties: {'status': 0, 'throughput': 13.641666666666667, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> productcatalogservice, Properties: {'status': 0, 'throughput': nan, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> productcatalogservice, Properties: {'status': 0, 'throughput': 309.8666666666667, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> productcatalogservice, Properties: {'status': 0, 'throughput': 480.2916666666667, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> productcatalogservice, Properties: {'status': 0, 'throughput': 23.73333333333333, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> shippingservice, Properties: {'status': 0, 'throughput': nan, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> shippingservice, Properties: {'status': 0, 'throughput': 491.98333333333335, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> shippingservice, Properties: {'status': 0, 'throughput': 768.2916666666666, 'color': green, 'name': 'status_0'}
# Adding edge: checkoutservice -> shippingservice, Properties: {'status': 0, 'throughput': 35.11666666666667, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> adservice, Properties: {'status': 1, 'throughput': nan, 'color': orange, 'name': 'status_1'}
# Adding edge: frontend -> adservice, Properties: {'status': 1, 'throughput': 2361.92, 'color': orange, 'name': 'status_1'}
# Adding edge: frontend -> adservice, Properties: {'status': 1, 'throughput': 3834.425833333333, 'color': orange, 'name': 'status_1'}
# Adding edge: frontend -> adservice, Properties: {'status': 1, 'throughput': 186.2125, 'color': orange, 'name': 'status_1'}
# Adding edge: frontend -> cartservice, Properties: {'status': 0, 'throughput': nan, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> cartservice, Properties: {'status': 0, 'throughput': 4464.316666666667, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> cartservice, Properties: {'status': 0, 'throughput': 7054.775, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> cartservice, Properties: {'status': 0, 'throughput': 403.4, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> checkoutservice, Properties: {'status': 0, 'throughput': nan, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> checkoutservice, Properties: {'status': 0, 'throughput': 315.21666666666664, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> checkoutservice, Properties: {'status': 1, 'throughput': 478.53333333333336, 'color': orange, 'name': 'status_1'}
# Adding edge: frontend -> checkoutservice, Properties: {'status': 1, 'throughput': 25.25, 'color': orange, 'name': 'status_1'}
# Adding edge: frontend -> currencyservice, Properties: {'status': 0, 'throughput': nan, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> currencyservice, Properties: {'status': 0, 'throughput': 12888.116666666669, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> currencyservice, Properties: {'status': 0, 'throughput': 19887.366666666665, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> currencyservice, Properties: {'status': 0, 'throughput': 1104.1333333333334, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> productcatalogservice, Properties: {'status': 0, 'throughput': nan, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> productcatalogservice, Properties: {'status': 0, 'throughput': 19192.835, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> productcatalogservice, Properties: {'status': 0, 'throughput': 30037.58333333333, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> productcatalogservice, Properties: {'status': 0, 'throughput': 1661.0958333333333, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> recommendationservice, Properties: {'status': 0, 'throughput': nan, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> recommendationservice, Properties: {'status': 0, 'throughput': 4310.683333333333, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> recommendationservice, Properties: {'status': 0, 'throughput': 6944.633333333333, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> recommendationservice, Properties: {'status': 1, 'throughput': 366.81666666666666, 'color': orange, 'name': 'status_1'}
# Adding edge: frontend -> shippingservice, Properties: {'status': 0, 'throughput': nan, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> shippingservice, Properties: {'status': 0, 'throughput': 1023.1708333333332, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> shippingservice, Properties: {'status': 0, 'throughput': 1592.8325, 'color': green, 'name': 'status_0'}
# Adding edge: frontend -> shippingservice, Properties: {'status': 0, 'throughput': 76.89583333333333, 'color': green, 'name': 'status_0'}
# Adding edge: loadgenerator -> frontend, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: loadgenerator -> frontend, Properties: {'status': 2, 'throughput': 34590.98333333333, 'color': red, 'name': 'status_2'}
# Adding edge: loadgenerator -> frontend, Properties: {'status': 2, 'throughput': 51170.25, 'color': red, 'name': 'status_2'}
# Adding edge: loadgenerator -> frontend, Properties: {'status': 2, 'throughput': nan, 'color': red, 'name': 'status_2'}
# Adding edge: recommendationservice -> productcatalogservice, Properties: {'status': 0, 'throughput': nan, 'color': green, 'name': 'status_0'}
# Adding edge: recommendationservice -> productcatalogservice, Properties: {'status': 0, 'throughput': 2906.863333333333, 'color': green, 'name': 'status_0'}
# Adding edge: recommendationservice -> productcatalogservice, Properties: {'status': 0, 'throughput': 4547.8, 'color': green, 'name': 'status_0'}
# Adding edge: recommendationservice -> productcatalogservice, Properties: {'status': 0, 'throughput': 256.7325, 'color': green, 'name': 'status_0'}
# ✅ Communication graph saved.

# %%
from raphtory.graphql import GraphServer

# Iniciar el servidor GraphQL
server = GraphServer(work_dir="graphs/").start()
client = server.get_client()

# Función para ejecutar consultas de forma segura
def safe_query(query, label):
    try:
        result = client.query(query)
        if "graph" in result or "__schema" in result:
            print(f"✅ {label}:")
            return result
        else:
            print(f"⚠️ Advertencia en {label}: Datos devueltos pero no en el formato esperado.")
            return result  # Devolver el resultado para inspección
    except Exception as e:
        print(f"❌ Excepción en {label}: {e}")
        return None

# Query 1: Propiedades de los nodos
node_properties_query = """
{
  graph(path: "communication_graph") {
    nodes {
      list {
        name
        degree
        properties {
          keys
          values {
            value
          }
        }
      }
    }
  }
}
"""
node_data = safe_query(node_properties_query, "Node Properties")
if node_data and "graph" in node_data:
    nodes = node_data["graph"]["nodes"]["list"]
    for node in nodes:
        properties = dict(zip(node["properties"]["keys"], [v["value"] for v in node["properties"]["values"]]))
        print(f"Node: {node['name']}, Degree: {node['degree']}, Properties: {properties}")

# Query 2: Propiedades de las aristas
# Query para obtener las propiedades de las aristas
edge_properties_query = """
{
  graph(path: "communication_graph") {
    edges {
      list {
        src {
          name
        }
        dst {
          name
        }
        properties {
          keys
          values {
            value
          }
        }
      }
    }
  }
}
"""

# Ejecutar la query
edge_data = safe_query(edge_properties_query, "Edge Properties")

# Procesar y mostrar los resultados
if edge_data and "graph" in edge_data:
    edges = edge_data["graph"]["edges"]["list"]
    for edge in edges:
        src = edge["src"]["name"]
        dst = edge["dst"]["name"]
        properties = dict(zip(edge["properties"]["keys"], [v["value"] for v in edge["properties"]["values"]]))
        print(f"Edge: {src} -> {dst}, Properties: {properties}")
else:
    print("❌ No se pudieron obtener los datos de las aristas.")

# # Query 3: Nodos con alto grado
# high_degree_nodes_query = """
# {
#   graph(path: "communication_graph") {
#     nodes {
#       list {
#         name
#         degree
#       }
#     }
#   }
# }
# """
# node_degree_data = safe_query(high_degree_nodes_query, "Node Degrees")
# if node_degree_data and "graph" in node_degree_data:
#     high_degree_nodes = [
#         node for node in node_degree_data["graph"]["nodes"]["list"]
#         if node["degree"] > 5
#     ]
#     print("🎯 High Degree Nodes:")
#     for node in high_degree_nodes:
#         print(f"Node: {node['name']}, Degree: {node['degree']}")
test_query = """
{
  graph(path: "communication_graph") {
    edges {
      list {
        src {
          name
        }
        dst {
          name
        }
      }
    }
  }
}
"""
test_data = safe_query(test_query, "Test Query")
print(test_data)

# Query 4: Introspección del esquema
introspection_query = """
{
  __schema {
    types {
      name
      fields {
        name
        type {
          name
          kind
        }
      }
    }
  }
}
"""
schema_info = safe_query(introspection_query, "Schema Introspection")
if schema_info and "__schema" in schema_info:
    types = schema_info["__schema"]["types"]
    for type_info in types:
        print(f"Type: {type_info['name']}")
        if type_info["fields"]:
            for field in type_info["fields"]:
                print(f"  Field: {field['name']}, Type: {field['type']['name']}, Kind: {field['type']['kind']}")
# Out:
# ✅ Node Properties:
# Node: checkoutservice, Degree: 7, Properties: {'role': 'destination'}
# Node: cartservice, Degree: 2, Properties: {'role': 'destination'}
# Node: currencyservice, Degree: 2, Properties: {'role': 'destination'}
# Node: emailservice, Degree: 1, Properties: {'role': 'destination'}
# Node: paymentservice, Degree: 1, Properties: {'role': 'destination'}
# Node: productcatalogservice, Degree: 3, Properties: {'role': 'destination'}
# Node: shippingservice, Degree: 2, Properties: {'role': 'destination'}
# Node: frontend, Degree: 8, Properties: {'role': 'destination'}
# Node: adservice, Degree: 1, Properties: {'role': 'destination'}
# Node: recommendationservice, Degree: 2, Properties: {'role': 'source'}
# Node: loadgenerator, Degree: 1, Properties: {'role': 'source'}
# ❌ Excepción en Edge Properties: error sending request for url (http://localhost:1736/)
# Caused by:
#   -> client error (SendRequest)
#   -> connection closed before message completed
# ❌ No se pudieron obtener los datos de las aristas.
# ✅ Test Query:
# {'graph': {'edges': {'list': [{'dst': {'name': 'cartservice'}, 'src': {'name': 'checkoutservice'}}, {'dst': {'name': 'currencyservice'}, 'src': {'name': 'checkoutservice'}}, {'dst': {'name': 'emailservice'}, 'src': {'name': 'checkoutservice'}}, {'dst': {'name': 'paymentservice'}, 'src': {'name': 'checkoutservice'}}, {'dst': {'name': 'productcatalogservice'}, 'src': {'name': 'checkoutservice'}}, {'dst': {'name': 'shippingservice'}, 'src': {'name': 'checkoutservice'}}, {'dst': {'name': 'adservice'}, 'src': {'name': 'frontend'}}, {'dst': {'name': 'cartservice'}, 'src': {'name': 'frontend'}}, {'dst': {'name': 'checkoutservice'}, 'src': {'name': 'frontend'}}, {'dst': {'name': 'currencyservice'}, 'src': {'name': 'frontend'}}, {'dst': {'name': 'productcatalogservice'}, 'src': {'name': 'frontend'}}, {'dst': {'name': 'recommendationservice'}, 'src': {'name': 'frontend'}}, {'dst': {'name': 'shippingservice'}, 'src': {'name': 'frontend'}}, {'dst': {'name': 'frontend'}, 'src': {'name': 'loadgenerator'}}, {'dst': {'name': 'productcatalogservice'}, 'src': {'name': 'recommendationservice'}}]}}}
# ✅ Schema Introspection:
# Type: Boolean
# Type: Edge
#   Field: layers, Type: None, Kind: NON_NULL
#   Field: excludeLayers, Type: None, Kind: NON_NULL
#   Field: layer, Type: None, Kind: NON_NULL
#   Field: excludeLayer, Type: None, Kind: NON_NULL
#   Field: window, Type: None, Kind: NON_NULL
#   Field: at, Type: None, Kind: NON_NULL
#   Field: latest, Type: None, Kind: NON_NULL
#   Field: snapshotAt, Type: None, Kind: NON_NULL
#   Field: snapshotLatest, Type: None, Kind: NON_NULL
#   Field: before, Type: None, Kind: NON_NULL
#   Field: after, Type: None, Kind: NON_NULL
#   Field: shrinkWindow, Type: None, Kind: NON_NULL
#   Field: shrinkStart, Type: None, Kind: NON_NULL
#   Field: shrinkEnd, Type: None, Kind: NON_NULL
#   Field: earliestTime, Type: Int, Kind: SCALAR
#   Field: firstUpdate, Type: Int, Kind: SCALAR
#   Field: latestTime, Type: Int, Kind: SCALAR
#   Field: lastUpdate, Type: Int, Kind: SCALAR
#   Field: time, Type: None, Kind: NON_NULL
#   Field: start, Type: Int, Kind: SCALAR
#   Field: end, Type: Int, Kind: SCALAR
#   Field: src, Type: None, Kind: NON_NULL
#   Field: dst, Type: None, Kind: NON_NULL
#   Field: id, Type: None, Kind: NON_NULL
#   Field: properties, Type: None, Kind: NON_NULL
#   Field: layerNames, Type: None, Kind: NON_NULL
#   Field: layerName, Type: None, Kind: NON_NULL
#   Field: explode, Type: None, Kind: NON_NULL
#   Field: explodeLayers, Type: None, Kind: NON_NULL
#   Field: history, Type: None, Kind: NON_NULL
#   Field: deletions, Type: None, Kind: NON_NULL
#   Field: isValid, Type: None, Kind: NON_NULL
#   Field: isActive, Type: None, Kind: NON_NULL
#   Field: isDeleted, Type: None, Kind: NON_NULL
#   Field: isSelfLoop, Type: None, Kind: NON_NULL
#   Field: nbr, Type: None, Kind: NON_NULL
# Type: EdgeAddition
# Type: EdgeSchema
#   Field: srcType, Type: None, Kind: NON_NULL
#   Field: dstType, Type: None, Kind: NON_NULL
#   Field: properties, Type: None, Kind: NON_NULL
# Type: FilterCondition
# Type: Float
# Type: GqlConstantProperties
#   Field: get, Type: GqlProp, Kind: OBJECT
#   Field: contains, Type: None, Kind: NON_NULL
#   Field: keys, Type: None, Kind: NON_NULL
#   Field: values, Type: None, Kind: NON_NULL
# Type: GqlDocument
#   Field: name, Type: None, Kind: NON_NULL
#   Field: entityType, Type: None, Kind: NON_NULL
#   Field: content, Type: None, Kind: NON_NULL
#   Field: embedding, Type: None, Kind: NON_NULL
#   Field: life, Type: None, Kind: NON_NULL
# Type: GqlEdges
#   Field: layers, Type: None, Kind: NON_NULL
#   Field: excludeLayers, Type: None, Kind: NON_NULL
#   Field: layer, Type: None, Kind: NON_NULL
#   Field: excludeLayer, Type: None, Kind: NON_NULL
#   Field: window, Type: None, Kind: NON_NULL
#   Field: at, Type: None, Kind: NON_NULL
#   Field: latest, Type: None, Kind: NON_NULL
#   Field: snapshotAt, Type: None, Kind: NON_NULL
#   Field: snapshotLatest, Type: None, Kind: NON_NULL
#   Field: before, Type: None, Kind: NON_NULL
#   Field: after, Type: None, Kind: NON_NULL
#   Field: shrinkWindow, Type: None, Kind: NON_NULL
#   Field: shrinkStart, Type: None, Kind: NON_NULL
#   Field: shrinkEnd, Type: None, Kind: NON_NULL
#   Field: explode, Type: None, Kind: NON_NULL
#   Field: explodeLayers, Type: None, Kind: NON_NULL
#   Field: start, Type: Int, Kind: SCALAR
#   Field: end, Type: Int, Kind: SCALAR
#   Field: count, Type: None, Kind: NON_NULL
#   Field: page, Type: None, Kind: NON_NULL
#   Field: list, Type: None, Kind: NON_NULL
# Type: GqlGraph
#   Field: uniqueLayers, Type: None, Kind: NON_NULL
#   Field: defaultLayer, Type: None, Kind: NON_NULL
#   Field: layers, Type: None, Kind: NON_NULL
#   Field: excludeLayers, Type: None, Kind: NON_NULL
#   Field: layer, Type: None, Kind: NON_NULL
#   Field: excludeLayer, Type: None, Kind: NON_NULL
#   Field: subgraph, Type: None, Kind: NON_NULL
#   Field: subgraphId, Type: None, Kind: NON_NULL
#   Field: subgraphNodeTypes, Type: None, Kind: NON_NULL
#   Field: excludeNodes, Type: None, Kind: NON_NULL
#   Field: excludeNodesId, Type: None, Kind: NON_NULL
#   Field: window, Type: None, Kind: NON_NULL
#   Field: at, Type: None, Kind: NON_NULL
#   Field: latest, Type: None, Kind: NON_NULL
#   Field: snapshotAt, Type: None, Kind: NON_NULL
#   Field: snapshotLatest, Type: None, Kind: NON_NULL
#   Field: before, Type: None, Kind: NON_NULL
#   Field: after, Type: None, Kind: NON_NULL
#   Field: shrinkWindow, Type: None, Kind: NON_NULL
#   Field: shrinkStart, Type: None, Kind: NON_NULL
#   Field: shrinkEnd, Type: None, Kind: NON_NULL
#   Field: created, Type: None, Kind: NON_NULL
#   Field: lastOpened, Type: None, Kind: NON_NULL
#   Field: lastUpdated, Type: None, Kind: NON_NULL
#   Field: earliestTime, Type: Int, Kind: SCALAR
#   Field: latestTime, Type: Int, Kind: SCALAR
#   Field: start, Type: Int, Kind: SCALAR
#   Field: end, Type: Int, Kind: SCALAR
#   Field: earliestEdgeTime, Type: Int, Kind: SCALAR
#   Field: latestEdgeTime, Type: Int, Kind: SCALAR
#   Field: countEdges, Type: None, Kind: NON_NULL
#   Field: countTemporalEdges, Type: None, Kind: NON_NULL
#   Field: searchEdgeCount, Type: None, Kind: NON_NULL
#   Field: countNodes, Type: None, Kind: NON_NULL
#   Field: searchNodeCount, Type: None, Kind: NON_NULL
#   Field: hasNode, Type: None, Kind: NON_NULL
#   Field: hasNodeId, Type: None, Kind: NON_NULL
#   Field: hasEdge, Type: None, Kind: NON_NULL
#   Field: hasEdgeId, Type: None, Kind: NON_NULL
#   Field: node, Type: Node, Kind: OBJECT
#   Field: nodeId, Type: Node, Kind: OBJECT
#   Field: nodes, Type: None, Kind: NON_NULL
#   Field: searchNodes, Type: None, Kind: NON_NULL
#   Field: fuzzySearchNodes, Type: None, Kind: NON_NULL
#   Field: edge, Type: Edge, Kind: OBJECT
#   Field: edgeId, Type: Edge, Kind: OBJECT
#   Field: edges, Type: None, Kind: NON_NULL
#   Field: searchEdges, Type: None, Kind: NON_NULL
#   Field: fuzzySearchEdges, Type: None, Kind: NON_NULL
#   Field: properties, Type: None, Kind: NON_NULL
#   Field: name, Type: None, Kind: NON_NULL
#   Field: path, Type: None, Kind: NON_NULL
#   Field: namespace, Type: None, Kind: NON_NULL
#   Field: schema, Type: None, Kind: NON_NULL
#   Field: algorithms, Type: None, Kind: NON_NULL
#   Field: sharedNeighbours, Type: None, Kind: NON_NULL
#   Field: exportTo, Type: None, Kind: NON_NULL
#   Field: nodeFilter, Type: None, Kind: NON_NULL
#   Field: edgeFilter, Type: None, Kind: NON_NULL
# Type: GqlGraphType
# Type: GqlGraphs
#   Field: name, Type: None, Kind: NON_NULL
#   Field: path, Type: None, Kind: NON_NULL
#   Field: namespace, Type: None, Kind: NON_NULL
#   Field: created, Type: None, Kind: NON_NULL
#   Field: lastOpened, Type: None, Kind: NON_NULL
#   Field: lastUpdated, Type: None, Kind: NON_NULL
# Type: GqlMutableEdge
#   Field: success, Type: None, Kind: NON_NULL
#   Field: edge, Type: None, Kind: NON_NULL
#   Field: src, Type: None, Kind: NON_NULL
#   Field: dst, Type: None, Kind: NON_NULL
#   Field: delete, Type: None, Kind: NON_NULL
#   Field: addConstantProperties, Type: None, Kind: NON_NULL
#   Field: updateConstantProperties, Type: None, Kind: NON_NULL
#   Field: addUpdates, Type: None, Kind: NON_NULL
# Type: GqlMutableGraph
#   Field: graph, Type: None, Kind: NON_NULL
#   Field: node, Type: GqlMutableNode, Kind: OBJECT
#   Field: addNode, Type: None, Kind: NON_NULL
#   Field: createNode, Type: None, Kind: NON_NULL
#   Field: addNodes, Type: None, Kind: NON_NULL
#   Field: edge, Type: GqlMutableEdge, Kind: OBJECT
#   Field: addEdge, Type: None, Kind: NON_NULL
#   Field: addEdges, Type: None, Kind: NON_NULL
#   Field: deleteEdge, Type: None, Kind: NON_NULL
#   Field: addProperties, Type: None, Kind: NON_NULL
#   Field: addConstantProperties, Type: None, Kind: NON_NULL
#   Field: updateConstantProperties, Type: None, Kind: NON_NULL
# Type: GqlMutableNode
#   Field: success, Type: None, Kind: NON_NULL
#   Field: node, Type: None, Kind: NON_NULL
#   Field: addConstantProperties, Type: None, Kind: NON_NULL
#   Field: setNodeType, Type: None, Kind: NON_NULL
#   Field: updateConstantProperties, Type: None, Kind: NON_NULL
#   Field: addUpdates, Type: None, Kind: NON_NULL
# Type: GqlNodes
#   Field: layers, Type: None, Kind: NON_NULL
#   Field: excludeLayers, Type: None, Kind: NON_NULL
#   Field: layer, Type: None, Kind: NON_NULL
#   Field: excludeLayer, Type: None, Kind: NON_NULL
#   Field: window, Type: None, Kind: NON_NULL
#   Field: at, Type: None, Kind: NON_NULL
#   Field: latest, Type: None, Kind: NON_NULL
#   Field: snapshotAt, Type: None, Kind: NON_NULL
#   Field: snapshotLatest, Type: None, Kind: NON_NULL
#   Field: before, Type: None, Kind: NON_NULL
#   Field: after, Type: None, Kind: NON_NULL
#   Field: shrinkWindow, Type: None, Kind: NON_NULL
#   Field: shrinkStart, Type: None, Kind: NON_NULL
#   Field: shrinkEnd, Type: None, Kind: NON_NULL
#   Field: typeFilter, Type: None, Kind: NON_NULL
#   Field: nodeFilter, Type: None, Kind: NON_NULL
#   Field: start, Type: Int, Kind: SCALAR
#   Field: end, Type: Int, Kind: SCALAR
#   Field: count, Type: None, Kind: NON_NULL
#   Field: page, Type: None, Kind: NON_NULL
#   Field: list, Type: None, Kind: NON_NULL
#   Field: ids, Type: None, Kind: NON_NULL
# Type: GqlPathFromNode
#   Field: layers, Type: None, Kind: NON_NULL
#   Field: excludeLayers, Type: None, Kind: NON_NULL
#   Field: layer, Type: None, Kind: NON_NULL
#   Field: excludeLayer, Type: None, Kind: NON_NULL
#   Field: window, Type: None, Kind: NON_NULL
#   Field: at, Type: None, Kind: NON_NULL
#   Field: snapshotLatest, Type: None, Kind: NON_NULL
#   Field: snapshotAt, Type: None, Kind: NON_NULL
#   Field: latest, Type: None, Kind: NON_NULL
#   Field: before, Type: None, Kind: NON_NULL
#   Field: after, Type: None, Kind: NON_NULL
#   Field: shrinkWindow, Type: None, Kind: NON_NULL
#   Field: shrinkStart, Type: None, Kind: NON_NULL
#   Field: shrinkEnd, Type: None, Kind: NON_NULL
#   Field: typeFilter, Type: None, Kind: NON_NULL
#   Field: start, Type: Int, Kind: SCALAR
#   Field: end, Type: Int, Kind: SCALAR
#   Field: count, Type: None, Kind: NON_NULL
#   Field: page, Type: None, Kind: NON_NULL
#   Field: list, Type: None, Kind: NON_NULL
#   Field: ids, Type: None, Kind: NON_NULL
# Type: GqlProp
#   Field: key, Type: None, Kind: NON_NULL
#   Field: asString, Type: None, Kind: NON_NULL
#   Field: value, Type: None, Kind: NON_NULL
# Type: GqlPropInput
# Type: GqlPropTuple
#   Field: time, Type: None, Kind: NON_NULL
#   Field: asString, Type: None, Kind: NON_NULL
#   Field: value, Type: None, Kind: NON_NULL
# Type: GqlPropValue
# Type: GqlProperties
#   Field: get, Type: GqlProp, Kind: OBJECT
#   Field: contains, Type: None, Kind: NON_NULL
#   Field: keys, Type: None, Kind: NON_NULL
#   Field: values, Type: None, Kind: NON_NULL
#   Field: temporal, Type: None, Kind: NON_NULL
#   Field: constant, Type: None, Kind: NON_NULL
# Type: GqlTemporalProp
#   Field: key, Type: None, Kind: NON_NULL
#   Field: history, Type: None, Kind: NON_NULL
#   Field: values, Type: None, Kind: NON_NULL
#   Field: at, Type: String, Kind: SCALAR
#   Field: latest, Type: String, Kind: SCALAR
#   Field: unique, Type: None, Kind: NON_NULL
#   Field: orderedDedupe, Type: None, Kind: NON_NULL
# Type: GqlTemporalProperties
#   Field: get, Type: GqlTemporalProp, Kind: OBJECT
#   Field: contains, Type: None, Kind: NON_NULL
#   Field: keys, Type: None, Kind: NON_NULL
#   Field: values, Type: None, Kind: NON_NULL
# Type: GqlVectorisedGraph
#   Field: algorithms, Type: None, Kind: NON_NULL
# Type: GraphAlgorithmPlugin
#   Field: shortest_path, Type: None, Kind: NON_NULL
#   Field: pagerank, Type: None, Kind: NON_NULL
# Type: GraphSchema
#   Field: nodes, Type: None, Kind: NON_NULL
#   Field: layers, Type: None, Kind: NON_NULL
# Type: ID
# Type: Int
# Type: LayerSchema
#   Field: name, Type: None, Kind: NON_NULL
#   Field: edges, Type: None, Kind: NON_NULL
# Type: MutRoot
#   Field: plugins, Type: None, Kind: NON_NULL
#   Field: deleteGraph, Type: None, Kind: NON_NULL
#   Field: newGraph, Type: None, Kind: NON_NULL
#   Field: moveGraph, Type: None, Kind: NON_NULL
#   Field: copyGraph, Type: None, Kind: NON_NULL
#   Field: uploadGraph, Type: None, Kind: NON_NULL
#   Field: sendGraph, Type: None, Kind: NON_NULL
# Type: MutationPlugin
#   Field: NoOps, Type: None, Kind: NON_NULL
# Type: Node
#   Field: id, Type: None, Kind: NON_NULL
#   Field: name, Type: None, Kind: NON_NULL
#   Field: layers, Type: None, Kind: NON_NULL
#   Field: excludeLayers, Type: None, Kind: NON_NULL
#   Field: layer, Type: None, Kind: NON_NULL
#   Field: excludeLayer, Type: None, Kind: NON_NULL
#   Field: window, Type: None, Kind: NON_NULL
#   Field: at, Type: None, Kind: NON_NULL
#   Field: latest, Type: None, Kind: NON_NULL
#   Field: snapshotAt, Type: None, Kind: NON_NULL
#   Field: snapshotLatest, Type: None, Kind: NON_NULL
#   Field: before, Type: None, Kind: NON_NULL
#   Field: after, Type: None, Kind: NON_NULL
#   Field: shrinkWindow, Type: None, Kind: NON_NULL
#   Field: shrinkStart, Type: None, Kind: NON_NULL
#   Field: shrinkEnd, Type: None, Kind: NON_NULL
#   Field: earliestTime, Type: Int, Kind: SCALAR
#   Field: firstUpdate, Type: Int, Kind: SCALAR
#   Field: latestTime, Type: Int, Kind: SCALAR
#   Field: lastUpdate, Type: Int, Kind: SCALAR
#   Field: start, Type: Int, Kind: SCALAR
#   Field: end, Type: Int, Kind: SCALAR
#   Field: history, Type: None, Kind: NON_NULL
#   Field: isActive, Type: None, Kind: NON_NULL
#   Field: nodeType, Type: String, Kind: SCALAR
#   Field: properties, Type: None, Kind: NON_NULL
#   Field: degree, Type: None, Kind: NON_NULL
#   Field: outDegree, Type: None, Kind: NON_NULL
#   Field: inDegree, Type: None, Kind: NON_NULL
#   Field: inComponent, Type: None, Kind: NON_NULL
#   Field: outComponent, Type: None, Kind: NON_NULL
#   Field: edges, Type: None, Kind: NON_NULL
#   Field: outEdges, Type: None, Kind: NON_NULL
#   Field: inEdges, Type: None, Kind: NON_NULL
#   Field: neighbours, Type: None, Kind: NON_NULL
#   Field: inNeighbours, Type: None, Kind: NON_NULL
#   Field: outNeighbours, Type: None, Kind: NON_NULL
# Type: NodeAddition
# Type: NodeSchema
#   Field: typeName, Type: None, Kind: NON_NULL
#   Field: properties, Type: None, Kind: NON_NULL
# Type: Operator
# Type: PagerankOutput
#   Field: name, Type: None, Kind: NON_NULL
#   Field: rank, Type: None, Kind: NON_NULL
# Type: PropertySchema
#   Field: key, Type: None, Kind: NON_NULL
#   Field: propertyType, Type: None, Kind: NON_NULL
#   Field: variants, Type: None, Kind: NON_NULL
# Type: QueryPlugin
#   Field: globalSearch, Type: None, Kind: NON_NULL
# Type: QueryRoot
#   Field: hello, Type: None, Kind: NON_NULL
#   Field: graph, Type: None, Kind: NON_NULL
#   Field: updateGraph, Type: None, Kind: NON_NULL
#   Field: vectorisedGraph, Type: GqlVectorisedGraph, Kind: OBJECT
#   Field: graphs, Type: None, Kind: NON_NULL
#   Field: plugins, Type: None, Kind: NON_NULL
#   Field: receiveGraph, Type: None, Kind: NON_NULL
# Type: ShortestPathOutput
#   Field: target, Type: None, Kind: NON_NULL
#   Field: nodes, Type: None, Kind: NON_NULL
# Type: String
# Type: TpropInput
# Type: Upload
# Type: VectorAlgorithmPlugin
#   Field: similaritySearch, Type: None, Kind: NON_NULL
# Type: __Directive
#   Field: name, Type: None, Kind: NON_NULL
#   Field: description, Type: String, Kind: SCALAR
#   Field: locations, Type: None, Kind: NON_NULL
#   Field: args, Type: None, Kind: NON_NULL
#   Field: isRepeatable, Type: None, Kind: NON_NULL
# Type: __DirectiveLocation
# Type: __EnumValue
#   Field: name, Type: None, Kind: NON_NULL
#   Field: description, Type: String, Kind: SCALAR
#   Field: isDeprecated, Type: None, Kind: NON_NULL
#   Field: deprecationReason, Type: String, Kind: SCALAR
# Type: __Field
#   Field: name, Type: None, Kind: NON_NULL
#   Field: description, Type: String, Kind: SCALAR
#   Field: args, Type: None, Kind: NON_NULL
#   Field: type, Type: None, Kind: NON_NULL
#   Field: isDeprecated, Type: None, Kind: NON_NULL
#   Field: deprecationReason, Type: String, Kind: SCALAR
# Type: __InputValue
#   Field: name, Type: None, Kind: NON_NULL
#   Field: description, Type: String, Kind: SCALAR
#   Field: type, Type: None, Kind: NON_NULL
#   Field: defaultValue, Type: String, Kind: SCALAR
# Type: __Schema
#   Field: description, Type: None, Kind: NON_NULL
#   Field: types, Type: None, Kind: NON_NULL
#   Field: queryType, Type: None, Kind: NON_NULL
#   Field: mutationType, Type: __Type, Kind: OBJECT
#   Field: subscriptionType, Type: __Type, Kind: OBJECT
#   Field: directives, Type: None, Kind: NON_NULL
# Type: __Type
#   Field: kind, Type: None, Kind: NON_NULL
#   Field: name, Type: String, Kind: SCALAR
#   Field: description, Type: String, Kind: SCALAR
#   Field: fields, Type: None, Kind: LIST
#   Field: interfaces, Type: None, Kind: LIST
#   Field: possibleTypes, Type: None, Kind: LIST
#   Field: enumValues, Type: None, Kind: LIST
#   Field: inputFields, Type: None, Kind: LIST
#   Field: ofType, Type: __Type, Kind: OBJECT
#   Field: specifiedByURL, Type: String, Kind: SCALAR
#   Field: isOneOf, Type: Boolean, Kind: SCALAR
# Type: __TypeKind
